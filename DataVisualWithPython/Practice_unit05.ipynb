# %% [markdown]
# ## 5. 내 생일의 기온 변화를 그래프로 그리기

# %%
import csv
import matplotlib.pyplot as plt

f=open('seoul.csv', encoding='cp949')
data = csv.reader(f)
next(data)
result =[]    # 최고 기온 데이터를 저장할 리스트 생성

for row in data:
    if row[4] != '':    # 최고 기온 데이터 값이 존재한다면
        result.append(float(row[4]))    # result 리스트에 최고 기온 값 추가

plt.plot(result, 'r')    # result 리스트에 저장된 값을 빨간색 그래프로 그리기
plt.show()    # 그래프 나타내기

# %%
# split() 함수 사용하기 

s ='hello, pthon'
print(s.split(','))

date='1997-12-19'
print(date.split('-'))

print(date.split('-')[0])
print(date.split('-')[1])
print(date.split('-')[2])
# Out:
# ['hello', ' pthon']
# ['1997', '12', '19']
# 1997
# 12
# 19

# %%
# 8월의 최고 기온 데이터만 추출하여 그래프로 그리기

import csv
import matplotlib.pyplot as plt

f=open('seoul.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
result=[]

for row in data:
    if row[4] != '':    # 최고 기온 데이터 값이 존재한다면
        if row[0].split('-')[1]=='08':    #  8월에 해당하는 값이라면
            result.append(float(row[4]))    # result 리스트에 최고 기온 값 추가
plt.plot(result, 'hotpink')    # result 리스트에 저장된 값을 hotpink 색으로 그리기
plt.show()    # 그래프 나타내기

# %%
import csv
import matplotlib.pyplot as plt

f=open('seoul.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
result=[]

for row in data:
    if row[4] !='':
        if row[0].split('-')[1]=='02' and row[0].split('-')[2]=='14':    # 2월 14일이라면
            result.append(float(row[4]))
plt.plot(result, 'hotpink')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f=open('seoul.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
high=[]   # 최고 기온 값을 저장할 리스트 생성
low=[]    # 최저 기온 값을 저장할 리스트 생성

for row in data:
    if row[4] != '' and row[3] != '':    # 최고 기온 값과 최저 기온 값이 존재한다면
            if int(row[0].split('-')[0]) >= 1983:    # 1983년 이후 데이터라면
                if row[0].split('-')[1] =='02' and row[0].split('-')[2] =='14':    # 2월 14일이라면
                    high.append(float(row[4]))    # 최고 기온 값을 high 리스트에 저장
                    low.append(float(row[3]))    # 최저 기온 값을 low 리스트에 저장

plt.rc('font', family='Malgun Gothic')
plt.plot(high, 'hotpink')
plt.plot(low, 'skyblue')
plt.show()    # 그래프로 나타내ㅣ

# %%
import csv
import matplotlib.pyplot as plt

f=open('seoul.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
high=[]   # 최고 기온 값을 저장할 리스트 생성
low=[]    # 최저 기온 값을 저장할 리스트 생성

for row in data:
    if row[4] !='' and row[3] != '':    # 최고 기온 값과 최저 기온 값이 존재한다면
        date=row[0].split('-')           # 날짜 값을 - 문자를 기준으로 구분하여 저장
        if int(date[0]) >= 1983:         # 1983년 이후 데이터라면
            if date[1]=='12' and date[2]=='19':    # 2월 14일이라면
                high.append(float(row[4]))    # 최고 기온 값을 high 리스트에 저장 
                low.append(float(row[3]))     # 최저 기온 값을 low 리스트에 저장
            
plt.rc('font', family='Malgun Gothic')         # 맑은 고딕을 기본 글꼴로 설정
plt.rcParams['axes.unicode_minus'] = False    # 마이너스 기호 깨짐 방지
plt.title('내 생일 기온 변화 그래프')         # 제목 설정
plt.plot(high, 'hotpink', label='high')
plt.plot(low, 'skyblue', label='low')
plt.legend()    # 범례 표시
plt.show()      # 그래프 그리기
