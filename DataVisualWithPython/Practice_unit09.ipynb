# %% [markdown]
# ## 9. 우리 동네 인구 구조를 파이 차트로 나타내기

# %%
import csv
f=open('gender.csv')
data=csv.reader(f)

m=[]
f=[]

name=input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0]:
        for i in row[3:104]:
            m.append(-int(i))
        for i in row[106:]:
            f.append(int(i))
        
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name+' 지역 남녀 성별 인구 분포')
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()

# 오류 발생: '제주특별자치도'라는 단어가 포함된 지역 이름이 총 46개 나옴
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 제주특별자치도
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b94ab0ee875d> in <module>
#      20 plt.rcParams['axes.unicode_minus'] = False
#      21 plt.title(name+' 지역 남녀 성별 인구 분포')
# ---> 22 plt.barh(range(101), m, label='남성')
#      23 plt.barh(range(101), f, label='여성')
#      24 plt.legend()
#
# C:\anaconda3\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2500 @_copy_docstring_and_deprecators(Axes.barh)
#    2501 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2502     return gca().barh(
#    2503         y, width, height=height, left=left, align=align, **kwargs)
#    2504
#
# C:\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2628         """
# ...

# %%
print(len(m), len(f))
# Out:
# 4646 4646

# %%
import csv
f = open('gender.csv')
data = csv.reader(f)

m = []
f = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(-int(i))
        for i in row[106:] :
            f.append(int(i))
        break    # 반복문 실행을 멈춤

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize = (10,5), dpi=300)
plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 제주특별자치도

# %%
# pie() 함수

import matplotlib.pyplot as plt
plt.pie([10,20])
plt.show()

# %%
# 동그란 원 그리기

import matplotlib.pyplot as plt
size = [2441, 2312, 1031, 1233]
plt.axis('equal')
plt.pie(size)
plt.show()

# %%
# 레이블, 비율 및 범례 추가하기

import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
size = [2441, 2312, 1031, 1233]
label = ['A형','B형','AB형', 'O형']
plt.axis('equal')
plt.pie(size, labels = label, autopct = '%.1f%%')   # 비율 및 범례 추가
plt.legend()
plt.show()

# %%
# 색 및 돌출 효과 정하기

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
size=[2441, 2312, 1031, 1233]
label = ['A형', 'B형', 'AB형', 'O형']
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color, explode=(0,0,0.1,0))
plt.show()

# %%
# 원하는 지역의 성별 인구를 파이 차트로 그리기

import csv
f=open('gender.csv')
data=csv.reader(f)
size=[]
name=input('찾고 싶은 지역의 이름을 알려주세요 : ')

for row in data:
    if name in row[0]:
        m = 0
        f = 0
        for i in range(101):
            m = m + int(row[i+3])
            f = f + int(row[i+106])
        break
size.append(m)
size.append(f)
print(size)

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
color = ['crimson', 'darkcyan']
plt.axis('equal')
plt.pie(size, labels=['남', '녀'], autopct='%.1f%%', colors=color, startangle=90)
plt.title(name+' 지역의 남녀 성별 비율')
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 제주특별자치도
# [335813, 331524]
